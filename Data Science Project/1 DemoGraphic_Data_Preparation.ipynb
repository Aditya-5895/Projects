# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ## Demographic

# %%
df = pd.ExcelFile('Zip Code Recommendations Data.xlsx')

# %%
y_data = pd.read_excel(df,'InputData')

# %%
demographic = pd.read_csv("zip_codes_2018_5yr.csv")
demographic.head()
# Out:
#    geo_id     do_date  total_pop  households  male_pop  female_pop  \
# 0   87537  2014-01-01       2510         856      1283        1227
# 1   87017  2014-01-01        346         112       150         196
# 2   87528  2014-01-01       3505         727      1758        1747
# 3   87533  2014-01-01        133          58        49          84
# 4   87511  2014-01-01       2896         787      1177        1719
#
#    median_age  male_under_5  male_5_to_9  male_10_to_14  ...  \
# 0        42.1            58           75             87  ...
# 1        50.9             0            0             12  ...
# 2        27.9           260          194            159  ...
# 3        25.8             0           12              8  ...
# 4        36.0           142           63             44  ...
#
#    management_business_sci_arts_employed  sales_office_employed  \
# 0                                    NaN                    NaN
# 1                                    NaN                    NaN
# 2                                    NaN                    NaN
# 3                                    NaN                    NaN
# 4                                    NaN                    NaN
#
#    in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# 0               304               171                 80        593
# 1                 0                27                 15         96
# 2               293               266                298       1237
# 3                24                 8                  7         58
# 4               263               107                163       1008
#
#    in_undergrad_college  speak_only_english_at_home  speak_spanish_at_home  \
# 0                    20                         NaN                    NaN
# 1                    40                         NaN                    NaN
# 2                   138                         NaN                    NaN
# 3                     3                         NaN                    NaN
# 4                   279                         NaN                    NaN
#
#    speak_spanish_at_home_low_english
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 240 columns]

# %%
demographic.columns = ['zip']+list(demographic.columns[1:])
demographic = demographic.drop('do_date',axis=1)
demographic.head()
# Out:
#      zip  total_pop  households  male_pop  female_pop  median_age  \
# 0  87537       2510         856      1283        1227        42.1
# 1  87017        346         112       150         196        50.9
# 2  87528       3505         727      1758        1747        27.9
# 3  87533        133          58        49          84        25.8
# 4  87511       2896         787      1177        1719        36.0
#
#    male_under_5  male_5_to_9  male_10_to_14  male_15_to_17  ...  \
# 0            58           75             87             52  ...
# 1             0            0             12             10  ...
# 2           260          194            159            121  ...
# 3             0           12              8              4  ...
# 4           142           63             44            123  ...
#
#    management_business_sci_arts_employed  sales_office_employed  \
# 0                                    NaN                    NaN
# 1                                    NaN                    NaN
# 2                                    NaN                    NaN
# 3                                    NaN                    NaN
# 4                                    NaN                    NaN
#
#    in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# 0               304               171                 80        593
# 1                 0                27                 15         96
# 2               293               266                298       1237
# 3                24                 8                  7         58
# 4               263               107                163       1008
#
#    in_undergrad_college  speak_only_english_at_home  speak_spanish_at_home  \
# 0                    20                         NaN                    NaN
# 1                    40                         NaN                    NaN
# 2                   138                         NaN                    NaN
# 3                     3                         NaN                    NaN
# 4                   279                         NaN                    NaN
#
#    speak_spanish_at_home_low_english
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 239 columns]

# %%
demographic.nunique()
# Out:
# zip                                  33120
# total_pop                            15532
# households                           10573
# male_pop                             11966
# female_pop                           12073
#                                      ...
# in_school                             8713
# in_undergrad_college                  3747
# speak_only_english_at_home               0
# speak_spanish_at_home                    0
# speak_spanish_at_home_low_english        0
# Length: 239, dtype: int64

# %%
demographic = demographic.dropna(axis=1,thresh=int(len(demographic)*0.5))
print(demographic.shape)
demographic.head()
# Out:
# (33120, 229)
#      zip  total_pop  households  male_pop  female_pop  median_age  \
# 0  87537       2510         856      1283        1227        42.1
# 1  87017        346         112       150         196        50.9
# 2  87528       3505         727      1758        1747        27.9
# 3  87533        133          58        49          84        25.8
# 4  87511       2896         787      1177        1719        36.0
#
#    male_under_5  male_5_to_9  male_10_to_14  male_15_to_17  ...  \
# 0            58           75             87             52  ...
# 1             0            0             12             10  ...
# 2           260          194            159            121  ...
# 3             0           12              8              4  ...
# 4           142           63             44            123  ...
#
#    occupation_production_transportation_material  occupation_sales_office  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
#
#    occupation_services  management_business_sci_arts_employed  \
# 0                  NaN                                    NaN
# 1                  NaN                                    NaN
# 2                  NaN                                    NaN
# 3                  NaN                                    NaN
# 4                  NaN                                    NaN
#
#    sales_office_employed  in_grades_1_to_4  in_grades_5_to_8  \
# 0                    NaN               304               171
# 1                    NaN                 0                27
# 2                    NaN               293               266
# 3                    NaN                24                 8
# 4                    NaN               263               107
#
#    in_grades_9_to_12  in_school  in_undergrad_college
# 0                 80        593                    20
# 1                 15         96                    40
# 2                298       1237                   138
# 3                  7         58                     3
# 4                163       1008                   279
#
# [5 rows x 229 columns]

# %%
demographic.shape
# Out:
# (33120, 229)

# %%
med_dict = dict(demographic.median())

# %%
demographic = demographic.fillna(value=med_dict,axis=0)
demographic.isnull().sum().sum()
# Out:
# 0

# %%
zip_demographic = pd.DataFrame()
for i in y_data['ZipCode']:
    zip_demographic = pd.concat([zip_demographic,demographic[demographic['zip']==i]])
print(zip_demographic.shape)
zip_demographic.head()
# Out:
# (324, 229)
#          zip  total_pop  households  male_pop  female_pop  median_age  \
# 23357  77072      61818       18096     30827       30991        32.6
# 27034  77083      79996       22434     38455       41541        33.5
# 16633  77587      17040        4615      9103        7937        28.7
# 10124  77002      13571        3739     11525        2046        32.7
# 11373  77003       9876        4544      5108        4768        33.3
#
#        male_under_5  male_5_to_9  male_10_to_14  male_15_to_17  ...  \
# 23357          2158         2094           2785           1572  ...
# 27034          2639         2851           2901           1920  ...
# 16633          1005          862            930            411  ...
# 10124            73            0             17             41  ...
# 11373           302          221            352             83  ...
#
#        occupation_production_transportation_material  occupation_sales_office  \
# 23357                                         4590.0                   5803.0
# 27034                                         5462.0                   9690.0
# 16633                                         1463.0                   1177.0
# 10124                                          105.0                    696.0
# 11373                                          531.0                    997.0
#
#        occupation_services  management_business_sci_arts_employed  \
# 23357               7922.0                                 5613.0
# 27034               9782.0                                 9531.0
# 16633               1472.0                                  894.0
# 10124                218.0                                 2886.0
# 11373                945.0                                 2819.0
#
#        sales_office_employed  in_grades_1_to_4  in_grades_5_to_8  \
# 23357                 5803.0              3593              4176
# 27034                 9690.0              4432              4777
# 16633                 1177.0              1461              1212
# 10124                  696.0                 0                 5
# 11373                  997.0               349               411
#
#        in_grades_9_to_12  in_school  in_undergrad_college
# 23357               4141      17999                  4044
# 27034               5122      24503                  6658
# 16633               1052       5092                   889
# 10124                171        842                   308
# 11373                280       2366                   670
#
# [5 rows x 229 columns]

# %%
correlation = abs(zip_demographic.corr())

# %%
corr = correlation.copy()
corr.head()
# Out:
#                  zip  total_pop  households  male_pop  female_pop  median_age  \
# zip         1.000000   0.029743    0.016000  0.028624    0.030696    0.113689
# total_pop   0.029743   1.000000    0.963111  0.997820    0.997985    0.289215
# households  0.016000   0.963111    1.000000  0.962337    0.959896    0.229058
# male_pop    0.028624   0.997820    0.962337  1.000000    0.991623    0.301526
# female_pop  0.030696   0.997985    0.959896  0.991623    1.000000    0.276190
#
#             male_under_5  male_5_to_9  male_10_to_14  male_15_to_17  ...  \
# zip             0.089805     0.082785       0.062806       0.069952  ...
# total_pop       0.923094     0.927036       0.918331       0.909182  ...
# households      0.863791     0.835959       0.817592       0.811140  ...
# male_pop        0.924767     0.924018       0.913752       0.903076  ...
# female_pop      0.917690     0.926127       0.918959       0.911315  ...
#
#             occupation_production_transportation_material  \
# zip                                              0.209253
# total_pop                                        0.787742
# households                                       0.707966
# male_pop                                         0.792113
# female_pop                                       0.780301
#
#             occupation_sales_office  occupation_services  \
# zip                        0.050157             0.019459
# total_pop                  0.951247             0.832116
# households                 0.943420             0.803681
# male_pop                   0.945196             0.840338
# female_pop                 0.953154             0.820791
#
#             management_business_sci_arts_employed  sales_office_employed  \
# zip                                      0.090344               0.050157
# total_pop                                0.794571               0.951247
# households                               0.851237               0.943420
# male_pop                                 0.787278               0.945196
# female_pop                               0.798317               0.953154
#
#             in_grades_1_to_4  in_grades_5_to_8  in_grades_9_to_12  in_school  \
# zip                 0.081818          0.065441           0.076974   0.034989
# total_pop           0.933360          0.928588           0.921773   0.957634
# households          0.836650          0.828326           0.823027   0.881277
# male_pop            0.927732          0.922559           0.913739   0.951965
# female_pop          0.934934          0.930568           0.925710   0.959149
#
#             in_undergrad_college
# zip                     0.051704
# total_pop               0.585985
# households              0.558271
# male_pop                0.584207
# female_pop              0.585285
#
# [5 rows x 229 columns]

# %%
k = 0
for col in zip_demographic.columns[1:]:
    try:
        l = list(corr.columns[(corr.loc[col]>0.8) & (corr.loc[col]<1)])
        if len(l)!=0:
            corr = corr.drop(l,axis=1)
            corr = corr.drop(l,axis=0)
            print(f' {k+1} iteration removed columns are : {l}\n ')
            k+=1
    except:
        pass
# Out:
#  1 iteration removed columns are : ['households', 'male_pop', 'female_pop', 'male_under_5', 'male_5_to_9', 'male_10_to_14', 'male_15_to_17', 'male_30_to_34', 'male_35_to_39', 'male_40_to_44', 'male_45_to_49', 'male_50_to_54', 'male_55_to_59', 'female_under_5', 'female_5_to_9', 'female_10_to_14', 'female_15_to_17', 'female_25_to_29', 'female_30_to_34', 'female_35_to_39', 'female_40_to_44', 'female_45_to_49', 'female_50_to_54', 'female_55_to_59', 'female_60_to_61', 'female_62_to_64', 'female_65_to_66', 'female_67_to_69', 'population_1_year_and_over', 'population_3_years_over', 'pop_16_over', 'pop_25_years_over', 'pop_25_64', 'not_hispanic_pop', 'income_50000_59999', 'income_60000_74999', 'income_75000_99999', 'income_100000_124999', 'pop_determined_poverty_status', 'housing_units', 'occupied_housing_units', 'dwellings_1_units_detached', 'married_households', 'family_households', 'children', 'owner_occupied_housing_units', 'mortgaged_housing_units', 'families_with_young_children', 'two_parent_families_with_young_children', 'two_parents_in_labor_force_families_with_young_children', 'two_parents_father_in_labor_force_families_with_young_children', 'commute_15_19_mins', 'commute_20_24_mins', 'commute_25_29_mins', 'commute_30_34_mins', 'commute_35_44_mins', 'commute_60_more_mins', 'commute_45_59_mins', 'commuters_16_over', 'two_cars', 'three_cars', 'four_more_cars', 'aggregate_travel_time_to_work', 'commuters_by_car_truck_van', 'commuters_by_carpool', 'commuters_drove_alone', 'associates_degree', 'high_school_diploma', 'less_one_year_college', 'one_year_more_college', 'high_school_including_ged', 'some_college_and_associates_degree', 'male_45_64_associates_degree', 'male_45_64_some_college', 'male_45_to_64', 'employed_pop', 'unemployed_pop', 'pop_in_labor_force', 'not_in_labor_force', 'workers_16_and_over', 'civilian_labor_force', 'employed_arts_entertainment_recreation_accommodation_food', 'employed_education_health_social', 'employed_finance_insurance_real_estate', 'employed_manufacturing', 'employed_other_services_not_public_admin', 'employed_retail_trade', 'employed_science_management_admin_waste', 'employed_transportation_warehousing_utilities', 'employed_wholesale_trade', 'occupation_sales_office', 'occupation_services', 'sales_office_employed', 'in_grades_1_to_4', 'in_grades_5_to_8', 'in_grades_9_to_12', 'in_school']
#
#  2 iteration removed columns are : ['male_20', 'male_21', 'female_18_to_19', 'female_20', 'female_21', 'in_undergrad_college']
#
#  3 iteration removed columns are : ['male_25_to_29', 'female_22_to_24']
#
#  4 iteration removed columns are : ['male_67_to_69', 'male_70_to_74']
#
#  5 iteration removed columns are : ['female_70_to_74', 'female_75_to_79']
#
#  6 iteration removed columns are : ['female_80_to_84']
#
#  7 iteration removed columns are : ['female_85_and_over']
#
#  8 iteration removed columns are : ['white_male_45_54', 'white_male_55_64', 'income_125000_149999', 'income_150000_199999', 'worked_at_home', 'bachelors_degree', 'masters_degree', 'bachelors_degree_2', 'bachelors_degree_or_higher_25_64', 'male_45_64_bachelors_degree', 'occupation_management_arts', 'management_business_sci_arts_employed']
#
#  9 iteration removed columns are : ['black_male_45_54', 'black_male_55_64']
#
#  10 iteration removed columns are : ['asian_male_45_54', 'asian_male_55_64']
#
#  11 iteration removed columns are : ['hispanic_male_45_54', 'hispanic_male_55_64', 'poverty', 'children_in_single_female_hh', 'one_parent_families_with_young_children', 'less_than_high_school_graduate', 'employed_construction', 'occupation_natural_resources_construction_maintenance', 'occupation_production_transportation_material']
#
#  12 iteration removed columns are : ['income_per_capita', 'renter_occupied_housing_units_paying_cash_median_gross_rent', 'median_rent']
#
#  13 iteration removed columns are : ['income_10000_14999', 'income_15000_19999', 'income_20000_24999', 'rent_burden_not_computed', 'rent_over_50_percent', 'no_car', 'no_cars']
#
#  14 iteration removed columns are : ['income_30000_34999', 'income_35000_39999', 'income_40000_44999', 'housing_units_renter_occupied', 'households_public_asst_or_food_stamps', 'rent_40_to_50_percent']
#
#  15 iteration removed columns are : ['one_car']
#
#  16 iteration removed columns are : ['graduate_professional_degree', 'male_45_64_graduate_degree']
#
#  17 iteration removed columns are : ['owner_occupied_housing_units_median_value', 'owner_occupied_housing_units_upper_value_quartile']
#
#  18 iteration removed columns are : ['dwellings_5_to_9_units', 'dwellings_10_to_19_units', 'rent_35_to_40_percent', 'rent_30_to_35_percent', 'rent_20_to_25_percent', 'rent_15_to_20_percent']
#
#  19 iteration removed columns are : ['rent_25_to_30_percent']
#
#  20 iteration removed columns are : ['housing_built_2000_to_2004']
#
#  21 iteration removed columns are : ['rent_10_to_15_percent', 'commute_10_14_mins']
#
#  22 iteration removed columns are : ['father_in_labor_force_one_parent_families_with_young_children']
#
#  23 iteration removed columns are : ['commuters_by_bus']

# %%
corr.shape
# Out:
# (60, 60)

# %%
zip_demographic = zip_demographic[corr.columns]
zip_demographic.head()
# Out:
#          zip  total_pop  median_age  male_18_to_19  male_22_to_24  \
# 23357  77072      61818        32.6            841           1491
# 27034  77083      79996        33.5           1197           2218
# 16633  77587      17040        28.7            326            334
# 10124  77002      13571        32.7            623           1156
# 11373  77003       9876        33.3             44            187
#
#        male_65_to_66  male_75_to_79  male_80_to_84  male_85_and_over  \
# 23357            561            337            231               191
# 27034            786            489            209               204
# 16633            122            165             81                77
# 10124            127             42             29                25
# 11373             28             65              0                 0
#
#        white_pop  ...  commuters_by_public_transportation  \
# 23357       3962  ...                              1286.0
# 27034       6750  ...                               710.0
# 16633       1353  ...                               104.0
# 10124       4786  ...                               315.0
# 11373       1873  ...                               373.0
#
#        commuters_by_subway_or_elevated  group_quarters  \
# 23357                              0.0             168
# 27034                              0.0              37
# 16633                             10.0               9
# 10124                             93.0            8395
# 11373                              7.0              48
#
#        male_45_64_less_than_9_grade  male_45_64_grade_9_12  \
# 23357                          1801                    867
# 27034                          1323                    626
# 16633                           542                    293
# 10124                            84                    378
# 11373                           317                    196
#
#        male_45_64_high_school  armed_forces  \
# 23357                    2012           0.0
# 27034                    2812           0.0
# 16633                     703           0.0
# 10124                     929           0.0
# 11373                     286           0.0
#
#        employed_agriculture_forestry_fishing_hunting_mining  \
# 23357                                              283.0
# 27034                                              562.0
# 16633                                               57.0
# 10124                                              384.0
# 11373                                              261.0
#
#        employed_information  employed_public_administration
# 23357                 507.0                           462.0
# 27034                 396.0                          1753.0
# 16633                  20.0                           154.0
# 10124                  80.0                            96.0
# 11373                  41.0                           194.0
#
# [5 rows x 60 columns]

# %%
y_data.columns = ['zip','Liking']
y_data.head(5)
# Out:
#      zip  Liking
# 0  77072     0.0
# 1  77083     0.0
# 2  77587     0.0
# 3  77002     1.0
# 4  77003     1.0

# %%
zip_demographic = zip_demographic.merge(y_data)
zip_demographic.head()
# Out:
#      zip  total_pop  median_age  male_18_to_19  male_22_to_24  male_65_to_66  \
# 0  77072      61818        32.6            841           1491            561
# 1  77083      79996        33.5           1197           2218            786
# 2  77587      17040        28.7            326            334            122
# 3  77002      13571        32.7            623           1156            127
# 4  77003       9876        33.3             44            187             28
#
#    male_75_to_79  male_80_to_84  male_85_and_over  white_pop  ...  \
# 0            337            231               191       3962  ...
# 1            489            209               204       6750  ...
# 2            165             81                77       1353  ...
# 3             42             29                25       4786  ...
# 4             65              0                 0       1873  ...
#
#    commuters_by_subway_or_elevated  group_quarters  \
# 0                              0.0             168
# 1                              0.0              37
# 2                             10.0               9
# 3                             93.0            8395
# 4                              7.0              48
#
#    male_45_64_less_than_9_grade  male_45_64_grade_9_12  \
# 0                          1801                    867
# 1                          1323                    626
# 2                           542                    293
# 3                            84                    378
# 4                           317                    196
#
#    male_45_64_high_school  armed_forces  \
# 0                    2012           0.0
# 1                    2812           0.0
# 2                     703           0.0
# 3                     929           0.0
# 4                     286           0.0
#
#    employed_agriculture_forestry_fishing_hunting_mining  employed_information  \
# 0                                              283.0                    507.0
# 1                                              562.0                    396.0
# 2                                               57.0                     20.0
# 3                                              384.0                     80.0
# 4                                              261.0                     41.0
#
#    employed_public_administration  Liking
# 0                           462.0     0.0
# 1                          1753.0     0.0
# 2                           154.0     0.0
# 3                            96.0     1.0
# 4                           194.0     1.0
#
# [5 rows x 61 columns]

# %%
zip_demographic.shape
# Out:
# (324, 61)

# %%
zip_demographic['Liking'].value_counts()
# Out:
# 1.0    13
# 0.0     3
# Name: Liking, dtype: int64

# %%
# zip_demographic.to_csv("Cleaned_DemoGraphic_data_2018.csv")
